# %%
ls
# Out:
#  finance.json  'Finance Processor.ipynb'  'Jupyter Init.ipynb'

# %%
filename = 'finance.json'

# %%
# imports
import json
from collections import namedtuple
from itertools import islice

# %%
json_row = namedtuple('JsonRow', 'email contact name room job')
def data():
    with open(filename) as f:
        j = json.load(f)
        entries = j['feed']['entry']
        for entry in entries:
            email = entry['gsx$email']['$t']
            contact = entry['gsx$contact']['$t']
            job = entry['gsx$duty']['$t']
            name = entry['gsx$name']['$t']
            room = entry['gsx$room']['$t']
            yield json_row(email, contact, name, room, job)

# %%
def data_list():
    return list(data())

# %%
list(islice(data_list(), 4))
# Out:
# [JsonRow(email='', contact='7115', name='Lawrence Semakula', room="Accountant General's Office", job='Accountant General'),
#  JsonRow(email='', contact='7117', name='Godfrey Ssemugoma', room='Financial Management Services', job='Ag.Director/FMS'),
#  JsonRow(email='', contact='7259', name='Aiden Rujumba', room='Financial Management Services', job='Ag. C/FMSD'),
#  JsonRow(email='', contact='7919', name='Jane Enyaku', room="Accountant General's Office", job='Personal Secretary/AG')]

# %%
rowtuple = namedtuple('row', 'firstName lastName middleName email job mobile roomContact, office')
def gen_rows():
    for _tuple in data():
        names = _tuple.name.split(' ')
        firstName = names[0]
        lastName = names[-1]
        middleName = None
        if len(names) == 3:
            middleName = names[1]
        yield rowtuple(firstName, lastName, middleName, _tuple.email, _tuple.job, None, _tuple.contact, _tuple.room)

# %%
def to_json():
    json_list = []
    for row in gen_rows():
        json_obj = {
            'firstName': row.firstName,
            'lastName': row.lastName,
            'middleName': row.middleName,
            'email': row.email,
            'job': row.job,
            'roomContact': row.roomContact,
            'office': row.office
        }
        json_list.append(json_obj)
    return json_list

# %%
to_json()
# Out:
# [{'email': '',
#   'firstName': 'Lawrence',
#   'job': 'Accountant General',
#   'lastName': 'Semakula',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7115'},
#  {'email': '',
#   'firstName': 'Godfrey',
#   'job': 'Ag.Director/FMS',
#   'lastName': 'Ssemugoma',
#   'middleName': None,
#   'office': 'Financial Management Services',
#   'roomContact': '7117'},
#  {'email': '',
#   'firstName': 'Aiden',
#   'job': 'Ag. C/FMSD',
#   'lastName': 'Rujumba',
#   'middleName': None,
#   'office': 'Financial Management Services',
#   'roomContact': '7259'},
#  {'email': '',
#   'firstName': 'Jane',
#   'job': 'Personal Secretary/AG',
#   'lastName': 'Enyaku',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7919'},
#  {'email': '',
#   'firstName': 'Arthur',
#   'job': 'Ag. Comm/IFMS',
#   'lastName': 'Mugweri',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7933'},
#  {'email': '',
#   'firstName': 'Daniel',
#   'job': 'Sen. Sytems Analyst',
#   'lastName': 'Lubowa',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7917'},
#  {'email': '',
#   'firstName': 'Edward',
#   'job': 'Office Attendant',
#   'lastName': 'Oweyesigire',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7256'},
#  {'email': '',
#   'firstName': 'Robert',
#   'job': 'Driver',
#   'lastName': 'Izimba',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7256'},
#  {'email': '',
#   'firstName': 'Prudence',
#   'job': 'AC/HR/Treasury',
#   'lastName': 'Rwangoga',
#   'middleName': 'Ayebazibwe',
#   'office': "Accountant General's Office",
#   'roomContact': '7273'},
#  {'email': '',
#   'firstName': 'Lucy',
#   'job': 'PHRO',
#   'lastName': 'Acen',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7296'},
#  {'email': '',
#   'firstName': 'Lindah',
#   'job': 'HRO',
#   'lastName': 'Nanziri',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7924'},
#  {'email': '',
#   'firstName': 'Nakyama',
#   'job': 'SHRO',
#   'lastName': 'Bridget',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7924'},
#  {'email': '',
#   'firstName': 'Owuma',
#   'job': 'Research Officer',
#   'lastName': 'Gilbert',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7924'},
#  {'email': '',
#   'firstName': 'Agnes',
#   'job': 'Records Assistant',
#   'lastName': 'Nayiga',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7924'},
#  {'email': '',
#   'firstName': 'Margrate',
#   'job': 'Accounts Assistant',
#   'lastName': 'Apio',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7924'},
#  {'email': '',
#   'firstName': 'Jennifer',
#   'job': 'Asst. Records Officer',
#   'lastName': 'Rugunda',
#   'middleName': 'Nyakato',
#   'office': "Accountant General's Office",
#   'roomContact': '7373'},
#  {'email': '',
#   'firstName': 'Steven',
#   'job': 'Records Assistant',
#   'lastName': 'Medo',
#   'middleName': 'Godfrey',
#   'office': "Accountant General's Office",
#   'roomContact': '7373'},
#  {'email': '',
#   'firstName': 'Agnes',
#   'job': 'Records Assistant',
#   'lastName': 'Naiga',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7373'},
#  {'email': '',
#   'firstName': 'Modo',
#   'job': 'Sen. Records Officer',
#   'lastName': 'Ruth',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7355'},
#  {'email': '',
#   'firstName': 'Jackline',
#   'job': 'Office Attendant',
#   'lastName': 'Adong',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7355'},
#  {'email': '',
#   'firstName': 'Joyce',
#   'job': 'Librarian',
#   'lastName': 'Acen',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7299'},
#  {'email': '',
#   'firstName': 'Mariam',
#   'job': 'Asst. Librarian',
#   'lastName': 'Mukabya',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7299'},
#  {'email': '',
#   'firstName': 'Catherine',
#   'job': 'Asst. Librarian',
#   'lastName': 'Kyomugisha',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7299'},
#  {'email': '',
#   'firstName': 'Wilberforce',
#   'job': 'Office Attendant',
#   'lastName': 'Wandera',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7298'},
#  {'email': '',
#   'firstName': 'Cecilia',
#   'job': 'Office Attendant',
#   'lastName': 'Nakiwala',
#   'middleName': None,
#   'office': "Accountant General's Office",
#   'roomContact': '7299'},
#  {'email': '',
#   'firstName': 'Livingstone',
#   'job': 'Accounts Asst./Cashier',
#   'lastName': 'Kiwanuka',
#   'middleName': None,
#   'office': 'Financial Management Services',
#   'roomContact': '7243'},
#  {'email': '',
#   'firstName': 'Betty',
#   'job': 'Personal Secretary',
#   'lastName': 'Namayanja',
#   'middleName': None,
#   'office': 'Financial Management Services',
#   'roomContact': '7252'},
#  {'email': '',
#   'firstName': 'Maris',
#   'job': 'Ag.Dir./DCP',
#   'lastName': 'Wanyera',
#   'middleName': None,
#   'office': 'Debt And Cash Policy',
#   'roomContact': '7162'},
#  {'email': '',
#   'firstName': 'Slyvia',
#   'job': 'Sec/Dir.DCP',
#   'lastName': 'Ahimbisibwe',
#   'middleName': None,
#   'office': 'Debt And Cash Policy',
#   'roomContact': '7314'},
#  {'email': '',
#   'firstName': 'Florence',
#   'job': 'Office Attendant',
#   'lastName': 'Nabinfa',
#   'middleName': None,
#   'office': 'Debt And Cash Policy',
#   'roomContact': '7314'},
#  {'email': '',
#   'firstName': 'Abidat',
#   'job': 'Office Attendant',
#   'lastName': 'Cherotich',
#   'middleName': None,
#   'office': 'Debt And Cash Policy',
#   'roomContact': '7314'},
#  {'email': '',
#   'firstName': 'Robert',
#   'job': 'Ag.Comm/CPD',
#   'lastName': 'Okudi',
#   'middleName': None,
#   'office': 'Cash Policy Department',
#   'roomContact': '7266'},
#  {'email': '',
#   'firstName': 'David',
#   'job': 'AC/Cash Policy',
#   'lastName': 'Wamai',
#   'middleName': None,
#   'office': 'Cash Policy Department',
#   'roomContact': '7306'},
#  {'email': '',
#   'firstName': 'Doreen',
#   'job': 'Economist',
#   'lastName': 'Kabejja',
#   'middleName': None,
#   'office': 'Cash Policy Department',
#   'roomContact': '7330'},
#  {'email': '',
#   'firstName': 'Rehema',
#   'job': 'Senior Statician',
#   'lastName': 'Nassazi',
#   'middleName': None,
#   'office': 'Cash Policy Department',
#   'roomContact': '7330'},
#  {'email': '',
#   'firstName': 'Joseph',
#   'job': 'Economist',
#   'lastName': 'Ahimbisibwe',
#   'middleName': None,
#   'office': 'Cash Policy Department',
#   'roomContact': '7276'},
#  {'email': '',
#   'firstName': 'Robert',
#   'job': 'Economist',
#   'lastName': 'Matsiko',
#   'middleName': None,
#   'office': 'Cash Policy Department',
#   'roomContact': '7276'},
#  {'email': '',
#   'firstName': 'Clives',
#   'job': 'Economist',
#   'lastName': 'Ainebyona',
#   'middleName': None,
#   'office': 'Cash Policy Department',
#   'roomContact': '7310'},
#  {'email': '',
#   'firstName': 'Ferdinand',
#   'job': 'IT Support Officer/DARC',
#   'lastName': 'Tumwebaze',
#   'middleName': None,
#   'office': 'Cash Policy Department',
#   'roomContact': '7123'},
#  {'email': '',
#   'firstName': 'Jane',
#   'job': 'Secretary/CPD',
#   'lastName': 'Mirembe',
#   'middleName': None,
#   'office': 'Cash Policy Department',
#   'roomContact': '7471'},
#  {'email': '',
#   'firstName': 'Douglas',
#   'job': 'Office Attendant',
#   'lastName': 'Nakabago',
#   'middleName': 'Sanon',
#   'office': 'Cash Policy Department',
#   'roomContact': '7312'},
#  {'email': '',
#   'firstName': 'Anold',
#   'job': 'Commissioner',
#   'lastName': 'Dhatemwa',
#   'middleName': 'Geoffrey',
#   'office': 'Debt Policy Issurance & Department',
#   'roomContact': '7279'},
#  {'email': '',
#   'firstName': 'Zerida',
#   'job': 'AC/DPID',
#   'lastName': 'Zigiti',
#   'middleName': None,
#   'office': 'Debt Policy Issurance & Department',
#   'roomContact': '7114'},
#  {'email': '',
#   'firstName': 'Simon',
#   'job': 'Principal Economist',
#   'lastName': 'Opolot',
#   'middleName': 'Peter',
#   'office': 'Debt Policy Issurance & Department',
#   'roomContact': '7310'},
#  {'email': '',
#   'firstName': 'Joy',
#   'job': 'Senior Economist',
#   'lastName': 'Gessa',
#   'middleName': None,
#   'office': 'Debt Policy Issurance & Department',
#   'roomContact': '7310'},
#  {'email': '',
#   'firstName': 'Daphine',
#   'job': 'Principal Economist',
#   'lastName': 'Rutazaana',
#   'middleName': None,
#   'office': 'Debt Policy Issurance & Department',
#   'roomContact': '7282'},
#  {'email': '',
#   'firstName': 'Samson',
#   'job': 'Senior Economist',
#   'lastName': 'Muwanguzi',
#   'middleName': None,
#   'office': 'Debt Policy Issurance & Department',
#   'roomContact': '7282'},
#  {'email': '',
#   'firstName': 'Menno',
#   'job': 'Senior Economist',
#   'lastName': 'Ven',
#   'middleName': None,
#   'office': 'Debt Policy Issurance & Department',
#   'roomContact': '7283'},
#  {'email': '',
#   'firstName': 'Christine',
#   'job': 'Senior Statician',
#   'lastName': 'Nakazibwe',
#   'middleName': None,
#   'office': 'Debt Policy Issurance & Department',
#   'roomContact': '7313'},
#  {'email': '',
#   'firstName': 'Brian',
#   'job': 'Senior Economist',
#   'lastName': 'Kanzira',
#   'middleName': None,
#   'office': 'Debt Policy Issurance & Department',
#   'roomContact': '7313'},
#  {'email': '',
#   'firstName': 'Doreen',
#   'job': 'Economist',
#   'lastName': 'Mutoni',
#   'middleName': None,
#   'office': 'Debt Policy Issurance & Department',
#   'roomContact': '7466'},
#  {'email': '',
#   'firstName': 'Gerald',
#   'job': 'Economist',
#   'lastName': 'Uchamgiu',
#   'middleName': None,
#   'office': 'Debt Policy Issurance & Department',
#   'roomContact': '7466'},
#  {'email': '',
#   'firstName': 'Michael',
#   'job': 'Economist',
#   'lastName': 'Ogole',
#   'middleName': None,
#   'office': 'Debt Policy Issurance & Department',
#   'roomContact': '7466'},
#  {'email': '',
#   'firstName': 'Wiajik',
#   'job': 'Secretary',
#   'lastName': 'Grace',
#   'middleName': None,
#   'office': 'Debt Policy Issurance & Department',
#   'roomContact': '7469'},
#  {'email': '',
#   'firstName': 'Betty',
#   'job': 'Office Attendant',
#   'lastName': 'Namuli',
#   'middleName': None,
#   'office': 'Debt Policy Issurance & Department',
#   'roomContact': '7469'},
#  {'email': '',
#   'firstName': 'Jenipher',
#   'job': 'Ag. Dir/ TSAM',
#   'lastName': 'Muhuruzi',
#   'middleName': None,
#   'office': 'Treasury Services & Assets Management',
#   'roomContact': '7112'},
#  {'email': '',
#   'firstName': 'Margaret',
#   'job': 'Sec/TSAM',
#   'lastName': 'Basaza',
#   'middleName': 'Mbona',
#   'office': 'Treasury Services & Assets Management',
#   'roomContact': '7312'},
#  {'email': '',
#   'firstName': 'Mubaraka',
#   'job': 'Ag. AC/TSD',
#   'lastName': 'Nasamba',
#   'middleName': None,
#   'office': 'Treasury Services',
#   'roomContact': '7286'},
#  {'email': '',
#   'firstName': 'Betty',
#   'job': 'Secretary',
#   'lastName': 'Kirya',
#   'middleName': 'N.',
#   'office': 'Treasury Services',
#   'roomContact': '7280'},
#  {'email': '',
#   'firstName': 'Nanteza',
#   'job': 'Office Attendant',
#   'lastName': 'Hadija',
#   'middleName': None,
#   'office': 'Treasury Services',
#   'roomContact': '7280'},
#  {'email': '',
#   'firstName': 'Maurine',
#   'job': 'Accountant',
#   'lastName': 'Kiconco',
#   'middleName': None,
#   'office': 'Treasury Services',
#   'roomContact': '7280'},
#  {'email': '',
#   'firstName': 'Libert',
#   'job': 'Accountant',
#   'lastName': 'Baluku',
#   'middleName': None,
#   'office': 'Treasury Services',
#   'roomContact': '7285'},
#  {'email': '',
#   'firstName': 'Peter',
#   'job': 'Accountant',
#   'lastName': 'Mutaawe',
#   'middleName': None,
#   'office': 'Treasury Services',
#   'roomContact': '7461'},
#  {'email': '',
#   'firstName': 'Apophia',
#   'job': 'Accountant',
#   'lastName': 'Akampurira',
#   'middleName': None,
#   'office': 'Treasury Services',
#   'roomContact': '7461'},
#  {'email': '',
#   'firstName': 'Immaculate',
#   'job': 'Accountant',
#   'lastName': 'Nabayinda',
#   'middleName': 'M',
#   'office': 'Treasury Services',
#   'roomContact': '7278'},
#  {'email': '',
#   'firstName': 'Hope',
#   'job': 'Accountant',
#   'lastName': 'Nesiho',
#   'middleName': 'Dombo',
#   'office': 'Treasury Services',
#   'roomContact': '7278'},
#  {'email': '',
#   'firstName': 'Ronald',
#   'job': 'Accountant',
#   'lastName': 'Turihoahabwe',
#   'middleName': None,
#   'office': 'Treasury Services',
#   'roomContact': '7447'},
#  {'email': '',
#   'firstName': 'Daniel',
#   'job': 'Ag. Comm/AMD',
#   'lastName': 'Kigenyi',
#   'middleName': None,
#   'office': 'Assets Management',
#   'roomContact': '7268'},
#  {'email': '',
#   'firstName': 'Pedson',
#   'job': 'Prin. Accountant',
#   'lastName': 'Twesigomwe',
#   'middleName': None,
#   'office': 'Assets Management',
#   'roomContact': '7431'},
#  {'email': '',
#   'firstName': 'Agnes',
#   'job': 'Secretary',
#   'lastName': 'Komugisha',
#   'middleName': None,
#   'office': 'Assets Management',
#   'roomContact': '7265'},
#  {'email': '',
#   'firstName': 'Nanteza',
#   'job': 'Office Attendant',
#   'lastName': 'Hadijah',
#   'middleName': None,
#   'office': 'Assets Management',
#   'roomContact': '7265'},
#  {'email': '',
#   'firstName': 'Irene',
#   'job': 'Accountant/ AMD',
#   'lastName': 'Nakanwagi',
#   'middleName': None,
#   'office': 'Assets Management',
#   'roomContact': '7265'},
#  {'email': '',
#   'firstName': 'Tabaro',
#   'job': 'Principal Accountant',
#   'lastName': 'Richard',
#   'middleName': None,
#   'office': 'Assets Management',
#   'roomContact': '7257'},
#  {'email': '',
#   'firstName': 'Godfrey',
#   'job': 'Accountant',
#   'lastName': 'Luggya',
#   'middleName': 'Makedi',
#   'office': 'Assets Management',
#   'roomContact': '7438'},
#  {'email': '',
#   'firstName': 'Peter',
#   'job': 'Accountant',
#   'lastName': 'Sekabanja',
#   'middleName': 'Mutawe',
#   'office': 'Assets Management',
#   'roomContact': '7280'},
#  {'email': '',
#   'firstName': 'Chris',
#   'job': 'Accountant',
#   'lastName': 'Otim',
#   'middleName': None,
#   'office': 'Assets Management',
#   'roomContact': '7264'},
#  {'email': '',
#   'firstName': 'Titus',
#   'job': 'Office Attendant',
#   'lastName': 'Watmon',
#   'middleName': None,
#   'office': 'Assets Management',
#   'roomContact': '7252'},
#  {'email': '',
#   'firstName': 'Lamula',
#   'job': 'Accountant',
#   'lastName': 'Nalunkuma',
#   'middleName': None,
#   'office': 'Assets Management',
#   'roomContact': '7264'},
#  {'email': '',
#   'firstName': 'Nsubuga',
#   'job': 'Accountant',
#   'lastName': 'Mayengo',
#   'middleName': 'Yusuf',
#   'office': 'Assets Management',
#   'roomContact': '7264/7392'},
#  {'email': '',
#   'firstName': 'Ann',
#   'job': 'Accountant',
#   'lastName': 'Natamba',
#   'middleName': None,
#   'office': 'Assets Management',
#   'roomContact': '7264/7392'},
#  {'email': '',
#   'firstName': 'SimonMakuyi',
#   'job': 'Accountant',
#   'lastName': 'SimonMakuyi',
#   'middleName': None,
#   'office': 'Assets Management',
#   'roomContact': '7265'},
#  {'email': '',
#   'firstName': 'Susan',
#   'job': 'Accountant',
#   'lastName': 'Ashaba',
#   'middleName': None,
#   'office': 'Assets Management',
#   'roomContact': '7264'},
#  {'email': '',
#   'firstName': 'Kanamwangi',
#   'job': 'Accountant',
#   'lastName': 'Nicholas',
#   'middleName': None,
#   'office': 'Assets Management',
#   'roomContact': '7264/7392'},
#  {'email': '',
#   'firstName': 'Harriet',
#   'job': 'Accountant/NAV Support',
#   'lastName': 'Namirembe',
#   'middleName': None,
#   'office': 'Assets Management',
#   'roomContact': '7444'},
#  {'email': '',
#   'firstName': 'David',
#   'job': 'Ag.Comm/Pr. Policy',
#   'lastName': 'Kiyingi',
#   'middleName': 'Nyimbwa',
#   'office': 'Procurement Policy And Management Department',
#   'roomContact': '7342'},
#  {'email': '',
#   'firstName': 'Muhammed',
#   'job': 'Prin.Procurement officer',
#   'lastName': 'Segonga',
#   'middleName': None,
#   'office': 'Procurement Policy And Management Department',
#   'roomContact': '7300'},
#  {'email': '',
#   'firstName': 'Alfred',
#   'job': 'Princ.Procurement officer',
#   'lastName': 'Lapyem',
#   'middleName': None,
#   'office': 'Procurement Policy And Management Department',
#   'roomContact': '7301'},
#  {'email': '',
#   'firstName': 'Daniel',
#   'job': 'Research Assistant',
#   'lastName': 'Olero',
#   'middleName': 'Ongom',
#   'office': 'Procurement Policy And Management Department',
#   'roomContact': '7270'},
#  {'email': '',
#   'firstName': 'Proscovia',
#   'job': 'Personal Secretary',
#   'lastName': 'Nakyeyune',
#   'middleName': None,
#   'office': 'Procurement Policy And Management Department',
#   'roomContact': '7363'},
#  {'email': '',
#   'firstName': 'Asiimwe',
#   'job': 'Procurement officer',
#   'lastName': 'Immaculate',
#   'middleName': None,
#   'office': 'Procurement Policy And Management Department',
#   'roomContact': '7270'},
#  {'email': '',
#   'firstName': 'Ritah',
#   'job': 'Office Attendant',
#   'lastName': 'Twikirize',
#   'middleName': None,
#   'office': 'Procurement Policy And Management Department',
#   'roomContact': '7363'},
#  {'email': '',
#   'firstName': 'Betty',
#   'job': 'Personal Secretary',
#   'lastName': 'Namayanja',
#   'middleName': None,
#   'office': 'Financial Management Services',
#   'roomContact': '7252'},
#  {'email': '',
#   'firstName': 'Livingstone',
#   'job': 'Accounts Asst./Cashier',
#   'lastName': 'Kiwanuka',
#   'middleName': None,
#   'office': 'Financial Management Services',
#   'roomContact': '7243'},
#  {'email': '',
#   'firstName': 'Tembo',
#   'job': 'Accountant',
#   'lastName': 'Hafsa',
#   'middleName': None,
#   'office': 'Financial Management Systems',
#   'roomContact': '7472'},
#  {'email': '',
#   'firstName': 'Tracy',
#   'job': 'Accountant',
#   'lastName': 'Atuhirwe',
#   'middleName': None,
#   'office': 'Financial Management Systems',
#   'roomContact': '7472'},
#  {'email': '',
#   'firstName': 'Edward',
#   'job': 'Accountant',
#   'lastName': 'Ekonga',
#   'middleName': None,
#   'office': 'Financial Management Systems',
#   'roomContact': '7472'},
#  {'email': '',
#   'firstName': 'Amis',
#   'job': 'Accountant',
#   'lastName': 'Musisi',
#   'middleName': None,
#   'office': 'Financial Management Systems',
#   'roomContact': '7472'},
#  {'email': '',
#   'firstName': 'Ivy',
#   'job': 'Accountant',
#   'lastName': 'Nantumbwe',
#   'middleName': None,
#   'office': 'Financial Management Systems',
#   'roomContact': '7472'},
#  {'email': '',
#   'firstName': 'Matia',
#   'job': 'Accountant',
#   'lastName': 'Mulumba',
#   'middleName': None,
#   'office': 'Financial Management Systems',
#   'roomContact': '7297'},
#  {'email': '',
#   'firstName': 'Aida',
#   'job': 'Accountant',
#   'lastName': 'Emadit',
#   'middleName': None,
#   'office': 'Financial Management Systems',
#   'roomContact': '7297'},
#  {'email': '',
#   'firstName': 'Alexandra',
#   'job': 'Accountant',
#   'lastName': 'Kalenda',
#   'middleName': None,
#   'office': 'Financial Management Systems',
#   'roomContact': '7297'},
#  {'email': '',
#   'firstName': 'Naome',
#   'job': 'Data contoller',
#   'lastName': 'Katafiire',
#   'middleName': None,
#   'office': 'Treasury Services Center',
#   'roomContact': '7272'},
#  {'email': '',
#   'firstName': 'Joseph',
#   'job': 'Office Attendant',
#   'lastName': 'Openy',
#   'middleName': None,
#   'office': 'Treasury Services Center',
#   'roomContact': '7272'},
#  {'email': '',
#   'firstName': 'Fay',
#   'job': 'IFMS Systems Officer',
#   'lastName': 'Ninsiima',
#   'middleName': None,
#   'office': 'Treasury Services Center',
#   'roomContact': '7305'},
#  {'email': '',
#   'firstName': 'Nabuwati',
#   'job': 'SA/Programmer',
#   'lastName': 'Babirye',
#   'middleName': None,
#   'office': 'Treasury Services Center',
#   'roomContact': '7440'},
#  {'email': '',
#   'firstName': 'Help',
#   'job': 'IFMS',
#   'lastName': 'Desk',
#   'middleName': None,
#   'office': 'Treasury Services Center',
#   'roomContact': '7305'},
#  {'email': '',
#   'firstName': 'Ambrose',
#   'job': 'Ag. Comm',
#   'lastName': 'Promise',
#   'middleName': None,
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7345'},
#  {'email': '',
#   'firstName': 'Martha',
#   'job': 'Secretary',
#   'lastName': 'Byekwaso',
#   'middleName': None,
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7267'},
#  {'email': '',
#   'firstName': 'Aziz',
#   'job': 'Ag. AC/PSAD',
#   'lastName': 'Ssetaala',
#   'middleName': None,
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7269'},
#  {'email': '',
#   'firstName': 'Yvone',
#   'job': 'Accountant',
#   'lastName': 'Kabyanga',
#   'middleName': None,
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7349'},
#  {'email': '',
#   'firstName': 'Flavia',
#   'job': 'Accountant',
#   'lastName': 'Mbasooka',
#   'middleName': 'Bukko',
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7349'},
#  {'email': '',
#   'firstName': 'Douglas',
#   'job': 'Accountant',
#   'lastName': 'Sseremba',
#   'middleName': None,
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7344'},
#  {'email': '',
#   'firstName': 'Steven',
#   'job': 'Accountant',
#   'lastName': 'Bameka',
#   'middleName': None,
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7344'},
#  {'email': '',
#   'firstName': 'Andrew',
#   'job': 'Accountant',
#   'lastName': 'Arinaitwe',
#   'middleName': None,
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7347'},
#  {'email': '',
#   'firstName': 'Barbara',
#   'job': 'Accountant',
#   'lastName': 'Rhoda',
#   'middleName': None,
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7347'},
#  {'email': '',
#   'firstName': 'Onesmus',
#   'job': 'Accountant',
#   'lastName': 'Akampamya',
#   'middleName': None,
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7346'},
#  {'email': '',
#   'firstName': 'Barbara',
#   'job': 'Accountant',
#   'lastName': 'Nakintu',
#   'middleName': None,
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7458'},
#  {'email': '',
#   'firstName': 'Paul',
#   'job': 'Accountant',
#   'lastName': 'Barasa',
#   'middleName': 'Dan',
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7346'},
#  {'email': '',
#   'firstName': 'Melanie',
#   'job': 'Accountant',
#   'lastName': 'Nansubuga',
#   'middleName': 'Kizito',
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7346'},
#  {'email': '',
#   'firstName': 'Elizabeth',
#   'job': 'Accountant',
#   'lastName': 'Tushemerirwe',
#   'middleName': None,
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7346'},
#  {'email': '',
#   'firstName': 'Apolo',
#   'job': 'Accountant',
#   'lastName': 'Fiona',
#   'middleName': None,
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7346'},
#  {'email': '',
#   'firstName': 'Innocent',
#   'job': 'Accountant',
#   'lastName': 'Ainebyona',
#   'middleName': None,
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7346'},
#  {'email': '',
#   'firstName': 'Maria',
#   'job': 'Records Asst.',
#   'lastName': 'Nabakooza',
#   'middleName': None,
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7267'},
#  {'email': '',
#   'firstName': 'Evas',
#   'job': 'Office Attendant',
#   'lastName': 'Musiime',
#   'middleName': None,
#   'office': 'Public Sector Accounts Department',
#   'roomContact': '7267'},
#  {'email': '',
#   'firstName': 'Ronald',
#   'job': 'Systems Accountant',
#   'lastName': 'Atuhairwe',
#   'middleName': None,
#   'office': 'Systems Accountants Datacenter',
#   'roomContact': '7386'},
#  {'email': '',
#   'firstName': 'Acheng',
#   'job': 'Systems Accountant',
#   'lastName': 'Enid',
#   'middleName': None,
#   'office': 'Systems Accountants Datacenter',
#   'roomContact': '7386'},
#  {'email': '',
#   'firstName': 'Macreen',
#   'job': 'Systems Accountant',
#   'lastName': 'Kyomuhangi',
#   'middleName': None,
#   'office': 'Systems Accountants Datacenter',
#   'roomContact': '7386'},
#  {'email': '',
#   'firstName': 'Keneth',
#   'job': 'Systems Accountant',
#   'lastName': 'Mugisha',
#   'middleName': None,
#   'office': 'Systems Accountants Datacenter',
#   'roomContact': '7386'},
#  {'email': '',
#   'firstName': 'Emmanuel',
#   'job': 'Systems Accountant',
#   'lastName': 'Kiwanuka',
#   'middleName': None,
#   'office': 'Systems Accountants Datacenter',
#   'roomContact': '7386'},
#  {'email': '',
#   'firstName': 'Gloria',
#   'job': 'Systems Accountant',
#   'lastName': 'Kansiime',
#   'middleName': None,
#   'office': 'Systems Accountants Datacenter',
#   'roomContact': '7388'},
#  {'email': '',
#   'firstName': 'Juliet',
#   'job': 'Systems Accountant',
#   'lastName': 'Sseraabidde',
#   'middleName': None,
#   'office': 'Systems Accountants Datacenter',
#   'roomContact': '7387'},
#  {'email': '',
#   'firstName': 'Akello',
#   'job': 'Systems Accountant',
#   'lastName': 'Kimberly',
#   'middleName': None,
#   'office': 'Systems Accountants Datacenter',
#   'roomContact': '7388'},
#  {'email': '',
#   'firstName': 'Akello',
#   'job': 'Systems Accountant',
#   'lastName': 'Ivy',
#   'middleName': None,
#   'office': 'Systems Accountants Datacenter',
#   'roomContact': '7387'},
#  {'email': '',
#   'firstName': 'Job',
#   'job': 'Systems Accountant',
#   'lastName': 'Mabuya',
#   'middleName': None,
#   'office': 'Systems Accountants Datacenter',
#   'roomContact': '7387'},
#  {'email': '',
#   'firstName': 'Joseph',
#   'job': 'Systems Accountant',
#   'lastName': 'Mwesigwa',
#   'middleName': None,
#   'office': 'Systems Accountants Datacenter',
#   'roomContact': '7387'},
#  {'email': '',
#   'firstName': 'Racheal',
#   'job': 'Systems Accountant',
#   'lastName': 'Kabagenyi',
#   'middleName': None,
#   'office': 'Systems Accountants Datacenter',
#   'roomContact': '7387'},
#  {'email': '',
#   'firstName': 'Francis',
#   'job': 'Systems Accountant',
#   'lastName': 'Jenalist',
#   'middleName': None,
#   'office': 'Systems Accountants Datacenter',
#   'roomContact': '7387'},
#  {'email': '',
#   'firstName': 'Maureen',
#   'job': 'Systems Accountant',
#   'lastName': 'Katushabe',
#   'middleName': None,
#   'office': 'Systems Accountants Datacenter',
#   'roomContact': '7387'},
#  {'email': '',
#   'firstName': 'Stephen',
#   'job': 'Commissioner',
#   'lastName': 'Ojiambo',
#   'middleName': None,
#   'office': 'Treasury Inspectorate & Policy',
#   'roomContact': '7118'},
#  {'email': '',
#   'firstName': 'Okwakol',
#   'job': 'Asst Commisioner',
#   'lastName': 'Micheal',
#   'middleName': None,
#   'office': 'Treasury Inspectorate & Policy',
#   'roomContact': '7295'},
#  {'email': '',
#   'firstName': 'Muhumuza',
#   'job': 'Accountant',
#   'lastName': 'Andrew',
#   'middleName': None,
#   'office': 'Treasury Inspectorate & Policy',
#   'roomContact': '7423'},
#  {'email': '',
#   'firstName': 'Baraka',
#   'job': 'Personal Secretary',
#   'lastName': 'Albina',
#   'middleName': None,
#   'office': 'Treasury Inspectorate & Policy',
#   'roomContact': '7258'},
#  {'email': '',
#   'firstName': 'Sarah',
#   'job': 'Office Attendant',
#   'lastName': 'Nasiige',
#   'middleName': None,
#   'office': 'Treasury Inspectorate & Policy',
#   'roomContact': '7258'},
#  {'email': '',
#   'firstName': 'Julius',
#   'job': 'Office Attendant',
#   'lastName': 'Okello',
#   'middleName': None,
#   'office': 'Treasury Inspectorate & Policy',
#   'roomContact': '7258'},
#  {'email': '',
#   'firstName': 'Deo',
#   'job': 'Accountant',
#   'lastName': 'Lutaaya',
#   'middleName': None,
#   'office': 'Treasury Inspectorate & Policy',
#   'roomContact': '7274'},
#  {'email': '',
#   'firstName': 'Jacob',
#   'job': 'Accountant',
#   'lastName': 'Kabigumira',
#   'middleName': None,
#   'office': 'Treasury Inspectorate & Policy',
#   'roomContact': '7274'},
#  {'email': '',
#   'firstName': 'Amina',
#   'job': 'Research Assistant',
#   'lastName': 'Wanjuzi',
#   'middleName': None,
#   'office': 'Treasury Inspectorate & Policy',
#   'roomContact': '7915'},
#  {'email': '',
#   'firstName': 'Joyce',
#   'job': 'Librarian',
#   'lastName': 'Aceng',
#   'middleName': None,
#   'office': 'Treasury Inspectorate & Policy',
#   'roomContact': '7299'},
#  {'email': '',
#   'firstName': 'Cecilia',
#   'job': 'Library Attendant',
#   'lastName': 'Nakiwala',
#   'middleName': None,
#   'office': 'Treasury Inspectorate & Policy',
#   'roomContact': '7299'},
#  {'email': '',
#   'firstName': 'Catherine',
#   'job': 'Assistant Librarian',
#   'lastName': 'Kyomugisha',
#   'middleName': None,
#   'office': 'Treasury Inspectorate & Policy',
#   'roomContact': '7299'},
#  {'email': '',
#   'firstName': 'Miriam',
#   'job': 'Assistant Librarian',
#   'lastName': 'Mukabya',
#   'middleName': None,
#   'office': 'Treasury Inspectorate & Policy',
#   'roomContact': '7299'},
#  {'email': '',
#   'firstName': 'Augustine',
#   'job': 'Accountant',
#   'lastName': 'Kalule',
#   'middleName': None,
#   'office': 'Treasury Inspectorate & Policy',
#   'roomContact': '7262/7385'},
#  {'email': '',
#   'firstName': 'Emmanuel',
#   'job': 'Principal Systems Officer',
#   'lastName': 'Katongole',
#   'middleName': None,
#   'office': 'Information Technology Office',
#   'roomContact': '7281'},
#  {'email': '',
#   'firstName': 'Paul',
#   'job': 'Systems Officer / Network',
#   'lastName': 'Lumala',
#   'middleName': None,
#   'office': 'Information Technology Office',
#   'roomContact': '7927'},
#  {'email': '',
#   'firstName': 'Daphine',
#   'job': 'Office Attendant',
#   'lastName': 'Namulindwa',
#   'middleName': None,
#   'office': 'Information Technology Office',
#   'roomContact': '7927'},
#  {'email': '',
#   'firstName': 'Mofaht',
#   'job': 'Ag AC/MIS',
#   'lastName': 'Masaba',
#   'middleName': 'R.',
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7936'},
#  {'email': '',
#   'firstName': 'Gilbert',
#   'job': 'Systems Officer',
#   'lastName': 'Mwesigye',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7457'},
#  {'email': '',
#   'firstName': 'Steven',
#   'job': 'Consultant/IFMS',
#   'lastName': 'Barungi',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7325'},
#  {'email': '',
#   'firstName': 'Rogers',
#   'job': 'IFMS Consultant',
#   'lastName': 'Baguma',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7921'},
#  {'email': '',
#   'firstName': 'Bernadette',
#   'job': 'IFMS Consultant',
#   'lastName': 'Nakabuye',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7918'},
#  {'email': '',
#   'firstName': 'Jenipher',
#   'job': 'IFMS Consultant',
#   'lastName': 'Kiiza',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7906'},
#  {'email': '',
#   'firstName': 'Norbert',
#   'job': 'IFMS Consultant',
#   'lastName': 'Okello',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7938'},
#  {'email': '',
#   'firstName': 'Erasmus',
#   'job': 'IFMS Database Admin',
#   'lastName': 'Sunday',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7932'},
#  {'email': '',
#   'firstName': 'Benjamin',
#   'job': 'Consultant/IFMS',
#   'lastName': 'Mwema',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7449'},
#  {'email': '',
#   'firstName': 'Hamis',
#   'job': 'Office Attendant',
#   'lastName': 'Musisi',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7916'},
#  {'email': '',
#   'firstName': 'Fred',
#   'job': 'IFMS Consultant',
#   'lastName': 'Okwangale',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7903'},
#  {'email': '',
#   'firstName': 'Stella',
#   'job': 'IT.Officer',
#   'lastName': 'Olinga',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7939'},
#  {'email': '',
#   'firstName': 'Busulwa',
#   'job': 'Systems Officer',
#   'lastName': 'Ronald',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7926'},
#  {'email': '',
#   'firstName': 'Helena',
#   'job': 'Systems Officer',
#   'lastName': 'Mpangana',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7926'},
#  {'email': '',
#   'firstName': 'Scarlet',
#   'job': 'Systems Officer',
#   'lastName': 'Kabahuma',
#   'middleName': None,
#   'office': 'Service Desk',
#   'roomContact': '7305'},
#  {'email': '',
#   'firstName': 'Ronald',
#   'job': 'IT.Officer',
#   'lastName': 'Etyeku',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7926'},
#  {'email': '',
#   'firstName': 'Saadi',
#   'job': 'IT.Officer',
#   'lastName': 'Lubega',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7926'},
#  {'email': '',
#   'firstName': 'Petra',
#   'job': 'SA/Programmer',
#   'lastName': 'Okot',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7925'},
#  {'email': '',
#   'firstName': 'Bernard',
#   'job': 'IT.Officer',
#   'lastName': 'Wakyaya',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7925'},
#  {'email': '',
#   'firstName': 'Ambrose',
#   'job': 'IT.Officer',
#   'lastName': 'Asiimwe',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7925'},
#  {'email': '',
#   'firstName': 'Eric',
#   'job': 'IT.Officer',
#   'lastName': 'Gabriel',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7925'},
#  {'email': '',
#   'firstName': 'Samson',
#   'job': 'SA/Programmer',
#   'lastName': 'Byereeta',
#   'middleName': 'L.',
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7940'},
#  {'email': '',
#   'firstName': 'Leona',
#   'job': 'Systems Analyst',
#   'lastName': 'Kwikiriza',
#   'middleName': 'Faith',
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7920'},
#  {'email': '',
#   'firstName': 'Monica',
#   'job': 'SA/Programmer',
#   'lastName': 'Mugisha',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7943'},
#  {'email': '',
#   'firstName': 'Jane',
#   'job': 'Systems Officer',
#   'lastName': 'Nyangoma',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7419'},
#  {'email': '',
#   'firstName': 'Charles',
#   'job': 'Systems Officer',
#   'lastName': 'Debuas',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7467'},
#  {'email': '',
#   'firstName': 'Tony',
#   'job': 'Senior IT.Officer/Data Centre',
#   'lastName': 'Yawe',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7934'},
#  {'email': '',
#   'firstName': 'David',
#   'job': 'System Analysist',
#   'lastName': 'Orech',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7923'},
#  {'email': '',
#   'firstName': 'Duncan',
#   'job': 'IT.Officer',
#   'lastName': 'Kagulu',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7502'},
#  {'email': '',
#   'firstName': 'Dorothy',
#   'job': 'Systems Analyst',
#   'lastName': 'Binkiya',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7913'},
#  {'email': '',
#   'firstName': 'Gilbert',
#   'job': 'Systems Analyst/DataCenter',
#   'lastName': 'Eriko',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS/IFMS',
#   'roomContact': '7379'},
#  {'email': '',
#   'firstName': 'Lydia',
#   'job': 'Sen. Production Officer',
#   'lastName': 'Tusingwire',
#   'middleName': None,
#   'office': 'Management Information Systems-MIS',
#   'roomContact': '7445'},
#  {'email': '',
#   'firstName': 'Fixon',
#   'job': 'Ag. Internal Auditor General',
#   'lastName': 'DR.',
#   'middleName': None,
#   'office': 'Directorate Of Internal Audit',
#   'roomContact': '7116'},
#  {'email': '',
#   'firstName': 'Stephen',
#   'job': 'Ag.C/Internal Auditor Mgt',
#   'lastName': 'Enabu',
#   'middleName': None,
#   'office': 'Directorate Of Internal Audit',
#   'roomContact': '7290'},
#  {'email': '',
#   'firstName': 'Alice',
#   'job': 'Ag. AC/Internal Audit',
#   'lastName': 'Nangoku',
#   'middleName': None,
#   'office': 'Directorate Of Internal Audit',
#   'roomContact': '7292'},
#  {'email': '',
#   'firstName': 'Josephine',
#   'job': 'Internal Auditor',
#   'lastName': 'Adukut',
#   'middleName': None,
#   'office': 'Directorate Of Internal Audit',
#   'roomContact': '7316'},
#  {'email': '',
#   'firstName': 'Moses',
#   'job': 'Internal Auditor',
#   'lastName': 'Waiswa',
#   'middleName': None,
#   'office': 'Directorate Of Internal Audit',
#   'roomContact': '7287'},
#  {'email': '',
#   'firstName': 'Sauba',
#   'job': 'Senior Internal Auditor',
#   'lastName': 'Mukaliyewujja',
#   'middleName': None,
#   'office': 'Directorate Of Internal Audit',
#   'roomContact': '7287'},
#  {'email': '',
#   'firstName': 'Hussen',
#   'job': 'Ag.C/Forensic&Risk Advisory',
#   'lastName': 'Isingoma',
#   'middleName': None,
#   'office': 'Forensics & Risk Management',
#   'roomContact': '7319'},
#  {'email': '',
#   'firstName': 'Paul',
#   'job': 'Internal Auditor',
#   'lastName': 'Ocheng',
#   'middleName': None,
#   'office': 'Forensics & Risk Management',
#   'roomContact': '7287/7339'},
#  {'email': '',
#   'firstName': 'Nanyondo',
#   'job': 'Ag.C/IT&Performance Aud.',
#   'lastName': 'Betty',
#   'middleName': None,
#   'office': 'IT & Performance AUDIT',
#   'roomContact': '7291'},
#  {'email': '',
#   'firstName': 'Samson',
#   'job': 'AC/Internal Audit',
#   'lastName': 'Sowate',
#   'middleName': None,
#   'office': 'IT & Performance AUDIT',
#   'roomContact': '7316'},
#  {'email': '',
#   'firstName': 'Prosper',
#   'job': 'Senior Internal Auditor',
#   'lastName': 'Twinamatsiko',
#   'middleName': None,
#   'office': 'IT & Performance AUDIT',
#   'roomContact': '7287'},
#  {'email': '',
#   'firstName': 'Allan',
#   'job': 'Internal Auditor',
#   'lastName': 'Ssekitoleko',
#   'middleName': 'B.',
#   'office': 'IT & Performance AUDIT',
#   'roomContact': '7287/7339'},
#  {'email': '',
#   'firstName': 'Moses',
#   'job': 'Internal Auditor',
#   'lastName': 'Nkwasibwe',
#   'middleName': None,
#   'office': 'IT & Performance AUDIT',
#   'roomContact': '7294'},
#  {'email': '',
#   'firstName': 'Flavia',
#   'job': 'Internal Auditor',
#   'lastName': 'Mutabule',
#   'middleName': None,
#   'office': 'IT & Performance AUDIT',
#   'roomContact': '7316'},
#  {'email': '',
#   'firstName': 'Bob',
#   'job': 'Sen.Internal Auditor',
#   'lastName': 'Kagaba',
#   'middleName': None,
#   'office': 'IT & Performance AUDIT',
#   'roomContact': '7294'},
#  {'email': '',
#   'firstName': 'Martha',
#   'job': 'Personal Secretary',
#   'lastName': 'Nagadya',
#   'middleName': None,
#   'office': 'IT & Performance AUDIT',
#   'roomContact': '7294'},
#  {'email': '',
#   'firstName': 'Tabisa',
#   'job': 'Personal Secretary',
#   'lastName': 'Akello',
#   'middleName': None,
#   'office': 'IT & Performance AUDIT',
#   'roomContact': '7380'},
#  {'email': '',
#   'firstName': 'Sally',
#   'job': 'Office Attendant',
#   'lastName': 'Ayeka',
#   'middleName': None,
#   'office': 'IT & Performance AUDIT',
#   'roomContact': '7294'},
#  {'email': '',
#   'firstName': 'Peter',
#   'job': 'National Coordinator',
#   'lastName': 'Dr.',
#   'middleName': 'Ngategize',
#   'office': 'Private Sector Development Unit',
#   'roomContact': '7323'},
#  {'email': '',
#   'firstName': 'Daina',
#   'job': 'Legal Regulatory officer',
#   'lastName': 'Nannono',
#   'middleName': 'M',
#   'office': 'Private Sector Development Unit',
#   'roomContact': '7188'},
#  {'email': '',
#   'firstName': 'Sarah',
#   'job': 'Competitiveness Analyst/ME',
#   'lastName': 'Kabasinguzi',
#   'middleName': None,
#   'office': 'Private Sector Development Unit',
#   'roomContact': '7302'},
#  {'email': '',
#   'firstName': 'Mayers',
#   'job': 'Value Chain Analyst',
#   'lastName': 'Asiimwe',
#   'middleName': None,
#   'office': 'Private Sector Development Unit',
#   'roomContact': '7302/4234704'},
#  {'email': '',
#   'firstName': 'Rogers',
#   'job': 'Accountant',
#   'lastName': 'Kwebangira',
#   'middleName': None,
#   'office': 'Private Sector Development Unit',
#   'roomContact': '7324'},
#  {'email': '',
#   'firstName': 'Robert',
#   'job': 'Sen.Competetiveness Analyst',
#   'lastName': 'Wamulimah',
#   'middleName': 'Paul',
#   'office': 'Private Sector Development Unit',
#   'roomContact': '7288'},
#  {'email': '',
#   'firstName': 'Richard',
#   'job': 'AC/CB &ED',
#   'lastName': 'Mubiru',
#   'middleName': None,
#   'office': 'Private Sector Development Unit',
#   'roomContact': '7304'},
#  {'email': '',
#   'firstName': 'Helen',
#   'job': 'Senior Personal Secretary',
#   'lastName': 'Twodo',
#   'middleName': None,
#   'office': 'Private Sector Development Unit',
#   'roomContact': '7322'},
#  {'email': '',
#   'firstName': 'Anthony',
#   'job': 'Office Attendant',
#   'lastName': 'Bugembe',
#   'middleName': None,
#   'office': 'Private Sector Development Unit',
#   'roomContact': '7322'},
#  {'email': '',
#   'firstName': 'Ruth',
#   'job': 'Project Cordinator',
#   'lastName': 'Kato',
#   'middleName': None,
#   'office': 'NAO Support Unit',
#   'roomContact': '7271'},
#  {'email': '',
#   'firstName': 'Barbra',
#   'job': 'Finance&Contracts Officer',
#   'lastName': 'Rwomushana',
#   'middleName': None,
#   'office': 'NAO Support Unit',
#   'roomContact': '7181'},
#  {'email': '',
#   'firstName': 'Francis',
#   'job': 'Finance&Admin Assistant',
#   'lastName': 'Okello',
#   'middleName': None,
#   'office': 'NAO Support Unit',
#   'roomContact': '7180'},
#  {'email': '',
#   'firstName': 'Eunice',
#   'job': 'Finance&Contracts Officer',
#   'lastName': 'Kyerabira',
#   'middleName': None,
#   'office': 'NAO Support Unit',
#   'roomContact': '7326'},
#  {'email': '',
#   'firstName': 'Anthony',
#   'job': 'Sector Coordinator',
#   'lastName': 'Mwanje',
#   'middleName': 'Kintu',
#   'office': 'Accountability Sector Secretariat',
#   'roomContact': '7508'},
#  {'email': '',
#   'firstName': 'Geoffrey',
#   'job': 'Public Fin. Mgt.Advisor',
#   'lastName': 'Kakara',
#   'middleName': None,
#   'office': 'Accountability Sector Secretariat',
#   'roomContact': '7284'},
#  {'email': '',
#   'firstName': 'Specio',
#   'job': 'Accounts Assistant',
#   'lastName': 'Agaba',
#   'middleName': None,
#   'office': 'Accountability Sector Secretariat',
#   'roomContact': '7414'},
#  {'email': '',
#   'firstName': 'Scovia',
#   'job': 'Jr. Technical Assistant',
#   'lastName': 'Kenaga',
#   'middleName': None,
#   'office': 'Accountability Sector Secretariat',
#   'roomContact': '7507'},
#  {'email': '',
#   'firstName': 'Nicodemus',
#   'job': 'Jr. Technical Assistant',
#   'lastName': 'Nayebare',
#   'middleName': None,
#   'office': 'Accountability Sector Secretariat',
#   'roomContact': '7507'},
#  {'email': '',
#   'firstName': 'Brenda',
#   'job': 'Office Attendant',
#   'lastName': 'Nantege',
#   'middleName': None,
#   'office': 'Accountability Sector Secretariat',
#   'roomContact': '7507'},
#  {'email': '',
#   'firstName': 'Gorreti',
#   'job': 'Technical Assistant',
#   'lastName': 'Kajumba',
#   'middleName': None,
#   'office': 'Accountability Sector Secretariat',
#   'roomContact': '7464'},
#  {'email': '',
#   'firstName': 'Anna',
#   'job': 'Administrative Assistant',
#   'lastName': 'Niyonzima',
#   'middleName': None,
#   'office': 'Accountability Sector Secretariat',
#   'roomContact': '7464'},
#  {'email': '',
#   'firstName': 'Betty',
#   'job': 'Under Secretary /AO',
#   'lastName': 'Kasimbazi',
#   'middleName': None,
#   'office': 'Administration',
#   'roomContact': '7108'},
#  {'email': '',
#   'firstName': 'Jolly',
#   'job': 'Secretary',
#   'lastName': 'Sebacuzi',
#   'middleName': None,
#   'office': 'Administration',
#   'roomContact': '7207'},
#  {'email': '',
#   'firstName': 'Margret',
#   'job': 'Office Attendant',
#   'lastName': 'Adyero',
#   'middleName': None,
#   'office': 'Administration',
#   'roomContact': '7207'},
#  {'email': '',
#   'firstName': 'Dr.',
#   'job': 'Principal Assistant Secretary',
#   'lastName': 'Ddamulira',
#   'middleName': None,
#   'office': 'Administration',
#   'roomContact': '7109'},
#  {'email': '',
#   'firstName': 'Rosemary',
#   'job': 'Secretary/PAS',
#   'lastName': 'Guzu',
#   'middleName': None,
#   'office': 'Administration',
#   'roomContact': '7208'},
#  {'email': '',
#   'firstName': 'Elijah',
#   'job': 'Office Attendant /PAS',
#   'lastName': 'Emapus',
#   'middleName': None,
#   'office': 'Administration',
#   'roomContact': '7208'},
#  {'email': '',
#   'firstName': 'Nathan',
#   'job': 'SAS/L/PA(MF)',
#   'lastName': 'Dawanah',
#   'middleName': 'Gessa',
#   'office': 'Administration',
#   'roomContact': '7119'},
#  {'email': '',
#   'firstName': 'Diana',
#   'job': 'SAS/G',
#   'lastName': 'Kabagambe',
#   'middleName': None,
#   'office': 'Administration',
#   'roomContact': '7211'},
#  {'email': '',
#   'firstName': 'Ronald',
#   'job': 'SAS/TO/PA(P)',
#   'lastName': 'Osekenye',
#   'middleName': None,
#   'office': 'Administration',
#   'roomContact': '7178'},
#  {'email': '',
#   'firstName': 'Charles',
#   'job': 'SAS',
#   'lastName': 'Wasswa',
#   'middleName': 'Jude',
#   'office': 'Administration',
#   'roomContact': '7212'},
#  {'email': '',
#   'firstName': 'Dorcus',
#   'job': 'SAS/PA (Hon. Minister)',
#   'lastName': 'Otim',
#   'middleName': None,
#   'office': 'Administration',
#   'roomContact': '7382'},
#  {'email': '',
#   'firstName': 'Aida',
#   'job': 'SAS/F',
#   'lastName': 'Nanzigwa',
#   'middleName': 'Batuusa',
#   'office': 'Administration',
#   'roomContact': '7378'},
#  {'email': '',
#   'firstName': 'Ronald',
#   'job': 'AS',
#   'lastName': 'Kironde',
#   'middleName': None,
#   'office': 'Administration',
#   'roomContact': '7213'},
#  {'email': '',
#   'firstName': 'Maryline',
#   'job': 'AS',
#   'lastName': 'Ogena',
#   'middleName': None,
#   'office': 'Administration',
#   'roomContact': '7214'},
#  {'email': '',
#   'firstName': 'Komugisa',
#   'job': 'AS',
#   'lastName': 'Rosette',
#   'middleName': None,
#   'office': 'Administration',
#   'roomContact': '7214'},
#  {'email': '',
#   'firstName': 'Stephen',
#   'job': 'Commisioner /CPA',
#   'lastName': 'Kasangaki',
#   'middleName': None,
#   'office': 'Cabinent And Parliament Affairs',
#   'roomContact': '7156'},
#  {'email': '',
#   'firstName': 'Miriam',
#   'job': 'Secretary/ CPA',
#   'lastName': 'Akol',
#   'middleName': None,
#   'office': 'Cabinent And Parliament Affairs',
#   'roomContact': '7127'},
#  {'email': '',
#   'firstName': 'Akiki',
#   'job': 'Economist',
#   'lastName': 'Tumusiime',
#   'middleName': 'Julius',
#   'office': 'Cabinent And Parliament Affairs',
#   'roomContact': '7186'},
#  {'email': '',
#   'firstName': 'Charles',
#   'job': 'AC/HRM/F',
#   'lastName': 'Ziraba',
#   'middleName': None,
#   'office': 'Human Resource Division',
#   'roomContact': '7124'},
#  {'email': '',
#   'firstName': 'Nelson',
#   'job': 'PHRO',
#   'lastName': 'Kahandi',
#   'middleName': 'E.',
#   'office': 'Human Resource Division',
#   'roomContact': '7121'},
#  {'email': '',
#   'firstName': 'Francis',
#   'job': 'SHRO',
#   'lastName': 'Geneeton',
#   'middleName': 'Emitu',
#   'office': 'Human Resource Division',
#   'roomContact': '7384'},
#  {'email': '',
#   'firstName': 'Nancy',
#   'job': 'Human Resource Officer',
#   'lastName': 'Nyinomujuni',
#   'middleName': None,
#   'office': 'Human Resource Division',
#   'roomContact': '7366'},
#  {'email': '',
#   'firstName': 'Edward',
#   'job': 'HRA',
#   'lastName': 'Mujoba',
#   'middleName': None,
#   'office': 'Human Resource Division',
#   'roomContact': '7366'},
#  {'email': '',
#   'firstName': 'Gladys',
#   'job': 'Pool Stenographer',
#   'lastName': 'Oyeru',
#   'middleName': None,
#   'office': 'Human Resource Division',
#   'roomContact': '7210'},
#  {'email': '',
#   'firstName': 'AsiyatiNamata',
#   'job': 'Office Attendant',
#   'lastName': 'AsiyatiNamata',
#   'middleName': None,
#   'office': 'Human Resource Division',
#   'roomContact': '7210'},
#  {'email': '',
#   'firstName': 'Patricia',
#   'job': 'Asst Comm/CAD',
#   'lastName': 'Iga',
#   'middleName': 'Nyachwo',
#   'office': 'Accounts Division',
#   'roomContact': '7238'},
#  {'email': '',
#   'firstName': 'Francis',
#   'job': 'Sen. Acct/CAD',
#   'lastName': 'Azabo',
#   'middleName': None,
#   'office': 'Accounts Division',
#   'roomContact': '7235'},
#  {'email': '',
#   'firstName': 'Irene',
#   'job': 'Accountant',
#   'lastName': 'Barasa',
#   'middleName': None,
#   'office': 'Accounts Division',
#   'roomContact': '7249'},
#  {'email': '',
#   'firstName': 'Hawah',
#   'job': 'Sen.Personal Secretary',
#   'lastName': 'Kigaaga',
#   'middleName': None,
#   'office': 'Accounts Division',
#   'roomContact': '7215'},
#  {'email': '',
#   'firstName': 'Charles',
#   'job': 'Accountant/Exam',
#   'lastName': 'Mukasa',
#   'middleName': None,
#   'office': 'Accounts Division',
#   'roomContact': '7237'},
#  {'email': '',
#   'firstName': 'Rogers',
#   'job': 'Accounts Asst./ Book keeping',
#   'lastName': 'Oyimo',
#   'middleName': None,
#   'office': 'Accounts Division',
#   'roomContact': '7251'},
#  {'email': '',
#   'firstName': 'Monica',
#   'job': 'Asst.Accountant',
#   'lastName': 'Kitimbo',
#   'middleName': None,
#   'office': 'Accounts Division',
#   'roomContact': '7251'},
#  {'email': '',
#   'firstName': 'Patrick',
#   'job': 'Sen. Acc. Assistant/Salaries',
#   'lastName': 'Katono',
#   'middleName': 'Muhairwe',
#   'office': 'Accounts Division',
#   'roomContact': '7236'},
# ...
#   'office': 'Budget Policy And Evaluation',
#   'roomContact': '7151'},
#  {'email': '',
#   'firstName': 'Esther',
#   'job': 'Senior Economist',
#   'lastName': 'Ayebare',
#   'middleName': None,
#   'office': 'Budget Policy And Evaluation',
#   'roomContact': '7275'},
#  {'email': '',
#   'firstName': 'Beth',
#   'job': 'Senior Economist',
#   'lastName': 'Ansiimire',
#   'middleName': None,
#   'office': 'Budget Policy And Evaluation',
#   'roomContact': '7150'},
#  {'email': '',
#   'firstName': 'Ivan',
#   'job': 'Economist',
#   'lastName': 'Kasozi',
#   'middleName': None,
#   'office': 'Budget Policy And Evaluation',
#   'roomContact': '7150'},
#  {'email': '',
#   'firstName': 'Arnold',
#   'job': 'Economist',
#   'lastName': 'Bigabwa',
#   'middleName': None,
#   'office': 'Budget Policy And Evaluation',
#   'roomContact': '7150'},
#  {'email': '',
#   'firstName': 'Emmanuel',
#   'job': 'Economist',
#   'lastName': 'Ogwang',
#   'middleName': None,
#   'office': 'Budget Policy And Evaluation',
#   'roomContact': '7150'},
#  {'email': '',
#   'firstName': 'Collin',
#   'job': 'Graduate Economist',
#   'lastName': 'Tumwiine',
#   'middleName': None,
#   'office': 'Budget Policy And Evaluation',
#   'roomContact': '7150'},
#  {'email': '',
#   'firstName': 'Phiona',
#   'job': 'Graduate Economist',
#   'lastName': 'Natamba',
#   'middleName': None,
#   'office': 'Budget Policy And Evaluation',
#   'roomContact': '7150'},
#  {'email': '',
#   'firstName': 'Carol',
#   'job': 'Database Programmer',
#   'lastName': 'C.A.Abigaba',
#   'middleName': None,
#   'office': 'Budget Policy And Evaluation',
#   'roomContact': '7151'},
#  {'email': '',
#   'firstName': 'Alinda',
#   'job': 'Economist',
#   'lastName': 'John',
#   'middleName': None,
#   'office': 'Budget Policy And Evaluation',
#   'roomContact': '7151'},
#  {'email': '',
#   'firstName': 'Lydia',
#   'job': 'Economist',
#   'lastName': 'Kobusinge',
#   'middleName': None,
#   'office': 'Budget Policy And Evaluation',
#   'roomContact': '7151'},
#  {'email': '',
#   'firstName': 'Stuart',
#   'job': 'Database Programmer',
#   'lastName': 'Katungi',
#   'middleName': None,
#   'office': 'Budget Policy And Evaluation',
#   'roomContact': '7151'},
#  {'email': '',
#   'firstName': 'Doreen',
#   'job': 'Database Programmer',
#   'lastName': 'Ekallam',
#   'middleName': 'Sakwa',
#   'office': 'Budget Policy And Evaluation',
#   'roomContact': '7151'},
#  {'email': '',
#   'firstName': 'Beatrice',
#   'job': 'Admnistration Officer',
#   'lastName': 'Ssekabembe',
#   'middleName': None,
#   'office': 'Budget Policy And Evaluation',
#   'roomContact': '7171'},
#  {'email': '',
#   'firstName': 'Racheal',
#   'job': 'Secretary/ BPD',
#   'lastName': 'Mutesi',
#   'middleName': None,
#   'office': 'Budget Policy And Evaluation',
#   'roomContact': '7171'},
#  {'email': '',
#   'firstName': 'Patrick',
#   'job': 'DST',
#   'lastName': 'Ocailap',
#   'middleName': None,
#   'office': '6th Floor',
#   'roomContact': '7105'},
#  {'email': '',
#   'firstName': 'Immaculate',
#   'job': 'Personal Secretary',
#   'lastName': 'Apuki',
#   'middleName': None,
#   'office': '6th Floor',
#   'roomContact': '7137'},
#  {'email': '',
#   'firstName': 'Zephar',
#   'job': 'Office Attendant',
#   'lastName': 'Bogere',
#   'middleName': None,
#   'office': '6th Floor',
#   'roomContact': '7137'},
#  {'email': '',
#   'firstName': 'Moses',
#   'job': 'Ag.Director Econ. Affairs',
#   'lastName': 'Kaggwa',
#   'middleName': None,
#   'office': '6th Floor',
#   'roomContact': '7107'},
#  {'email': '',
#   'firstName': 'Joyce',
#   'job': 'Secretary/DEA',
#   'lastName': 'Mudondo',
#   'middleName': None,
#   'office': '6th Floor',
#   'roomContact': '7139'},
#  {'email': '',
#   'firstName': 'Gladys',
#   'job': 'Office Attendant',
#   'lastName': 'Nambozo',
#   'middleName': None,
#   'office': '6th Floor',
#   'roomContact': '7139'},
#  {'email': '',
#   'firstName': 'Kenneth',
#   'job': 'Director Budget',
#   'lastName': 'Mugambe',
#   'middleName': None,
#   'office': '6th Floor',
#   'roomContact': '7106'},
#  {'email': '',
#   'firstName': 'Charles',
#   'job': 'Advisor Budget',
#   'lastName': 'Byaruhanga',
#   'middleName': None,
#   'office': '6th Floor',
#   'roomContact': '7147'},
#  {'email': '',
#   'firstName': 'Rosemary',
#   'job': 'Sen Personal Secretary /DB',
#   'lastName': 'Amoding',
#   'middleName': None,
#   'office': '6th Floor',
#   'roomContact': '7138'},
#  {'email': '',
#   'firstName': 'Ruth',
#   'job': 'Office Attendant',
#   'lastName': 'Nantaba',
#   'middleName': None,
#   'office': '6th Floor',
#   'roomContact': '7138'},
#  {'email': '',
#   'firstName': 'Monday',
#   'job': 'Office Attendant',
#   'lastName': 'Sylvester',
#   'middleName': 'Brian',
#   'office': '6th Floor',
#   'roomContact': '7138'},
#  {'email': '',
#   'firstName': 'Ismael',
#   'job': 'Com/PAD',
#   'lastName': 'Magona',
#   'middleName': None,
#   'office': 'Public Administration Department',
#   'roomContact': '7144'},
#  {'email': '',
#   'firstName': 'Zziwa',
#   'job': 'AC/PAD',
#   'lastName': 'Moses',
#   'middleName': None,
#   'office': 'Public Administration Department',
#   'roomContact': '7142'},
#  {'email': '',
#   'firstName': 'Annet',
#   'job': 'Personal Secretary',
#   'lastName': 'Mugasa',
#   'middleName': None,
#   'office': 'Public Administration Department',
#   'roomContact': '7145'},
#  {'email': '',
#   'firstName': 'Rashidah',
#   'job': 'Personal Secretary/CPAD',
#   'lastName': 'Kiggundu',
#   'middleName': 'Nagawa',
#   'office': 'Public Administration Department',
#   'roomContact': '7141'},
#  {'email': '',
#   'firstName': 'Jane',
#   'job': 'Principal Economist',
#   'lastName': 'Namayanja',
#   'middleName': None,
#   'office': 'Public Administration Department',
#   'roomContact': '7329'},
#  {'email': '',
#   'firstName': 'Mohammed',
#   'job': 'Principal Economist',
#   'lastName': 'Kabaale',
#   'middleName': None,
#   'office': 'Public Administration Department',
#   'roomContact': '7143'},
#  {'email': '',
#   'firstName': 'Godwin',
#   'job': 'Economist',
#   'lastName': 'Nuwamanya',
#   'middleName': None,
#   'office': 'Public Administration Department',
#   'roomContact': '7150'},
#  {'email': '',
#   'firstName': 'Tito',
#   'job': 'Economist',
#   'lastName': 'Okello',
#   'middleName': None,
#   'office': 'Public Administration Department',
#   'roomContact': '7160'},
#  {'email': '',
#   'firstName': 'Nancy',
#   'job': 'Economist',
#   'lastName': 'Rukundo',
#   'middleName': None,
#   'office': 'Public Administration Department',
#   'roomContact': '7146'},
#  {'email': '',
#   'firstName': 'Segamwenge',
#   'job': 'Senior Economist',
#   'lastName': 'S.Geofrey',
#   'middleName': None,
#   'office': 'Public Administration Department',
#   'roomContact': '7146'},
#  {'email': '',
#   'firstName': 'Tereza',
#   'job': 'Principal Economist',
#   'lastName': 'Namwach',
#   'middleName': None,
#   'office': 'Public Administration Department',
#   'roomContact': '7146'},
#  {'email': '',
#   'firstName': 'Angella',
#   'job': 'Economist',
#   'lastName': 'Mutesi',
#   'middleName': None,
#   'office': 'Public Administration Department',
#   'roomContact': '7474'},
#  {'email': '',
#   'firstName': 'George',
#   'job': 'Driver',
#   'lastName': 'Magoola',
#   'middleName': None,
#   'office': 'Public Administration Department',
#   'roomContact': '7122'},
#  {'email': '',
#   'firstName': 'Lawrence',
#   'job': 'Office Attendant',
#   'lastName': 'Kazibwe',
#   'middleName': None,
#   'office': 'Public Administration Department',
#   'roomContact': '7145'},
#  {'email': '',
#   'firstName': 'Dennis',
#   'job': 'FINMAP',
#   'lastName': 'Girardot',
#   'middleName': None,
#   'office': 'Public Administration Department',
#   'roomContact': '7951'},
#  {'email': '',
#   'firstName': 'Hon.',
#   'job': 'Minister /MFPED',
#   'lastName': 'Kasaija',
#   'middleName': 'Matia',
#   'office': '7th Floor',
#   'roomContact': '7501'},
#  {'email': '',
#   'firstName': 'Lilian',
#   'job': 'Secretary /MFPED',
#   'lastName': 'Musoke',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7131'},
#  {'email': '',
#   'firstName': 'Jessica',
#   'job': 'Secretary/MFPED',
#   'lastName': 'Katongole',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7439'},
#  {'email': '',
#   'firstName': 'Samuel',
#   'job': 'Office Attendant',
#   'lastName': 'Obityo',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7131'},
#  {'email': '',
#   'firstName': 'Geoffrey',
#   'job': 'Office Attendant',
#   'lastName': 'Maruki',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7131'},
#  {'email': '',
#   'firstName': 'Hon.',
#   'job': 'Minister of State/Planning',
#   'lastName': 'Bahati',
#   'middleName': 'David',
#   'office': '7th Floor',
#   'roomContact': '7101'},
#  {'email': '',
#   'firstName': 'Florence',
#   'job': 'Prin. Personal Secretary/PL',
#   'lastName': 'Tatamba',
#   'middleName': 'Joan',
#   'office': '7th Floor',
#   'roomContact': '7132'},
#  {'email': '',
#   'firstName': 'Grace',
#   'job': 'Steno Secretary',
#   'lastName': 'Ayerango',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7307'},
#  {'email': '',
#   'firstName': 'Martin',
#   'job': 'Office Attendant (PL)',
#   'lastName': 'Mitchell',
#   'middleName': 'Mayanja',
#   'office': '7th Floor',
#   'roomContact': '7132'},
#  {'email': '',
#   'firstName': 'Hon',
#   'job': 'Minister of State(PR&INV)',
#   'lastName': 'Anite',
#   'middleName': 'Evelyn',
#   'office': '7th Floor',
#   'roomContact': '7102'},
#  {'email': '',
#   'firstName': 'Monica',
#   'job': 'Secretary /(PR&INV)',
#   'lastName': 'Kwikiriza',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7133'},
#  {'email': '',
#   'firstName': 'Rosemary',
#   'job': 'Office Attendant//PR&INV)',
#   'lastName': 'Ayamo',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7133'},
#  {'email': '',
#   'firstName': 'Hebert',
#   'job': 'Driver (PL)',
#   'lastName': 'Aheebwa',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7133'},
#  {'email': '',
#   'firstName': 'Hon.',
#   'job': 'Minister of State/GD',
#   'lastName': 'Ajedra',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7103'},
#  {'email': '',
#   'firstName': 'Annet',
#   'job': 'Personal Secretary /GD',
#   'lastName': 'Nabunya',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7134'},
#  {'email': '',
#   'firstName': 'Grace',
#   'job': 'Office Attendant /GD',
#   'lastName': 'Aneno',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7233'},
#  {'email': '',
#   'firstName': 'Chistopher',
#   'job': 'Office Attendant/GD',
#   'lastName': 'Bithum',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7233'},
#  {'email': '',
#   'firstName': 'Keith',
#   'job': 'PS/ST',
#   'lastName': 'Muhakanizi',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7104'},
#  {'email': '',
#   'firstName': 'Sauda',
#   'job': 'Sen. Personal Secretary/PS',
#   'lastName': 'Kisiki',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7135'},
#  {'email': '',
#   'firstName': 'Layton',
#   'job': 'Sen. Personal Secretary/PS',
#   'lastName': 'Nanjobe',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7135'},
#  {'email': '',
#   'firstName': 'Tom',
#   'job': 'Office Attendant/PS',
#   'lastName': 'Kirya',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7135'},
#  {'email': '',
#   'firstName': 'Justine',
#   'job': 'Receptionist Floor 7',
#   'lastName': 'Sendi',
#   'middleName': None,
#   'office': '7th Floor',
#   'roomContact': '7136'},
#  {'email': '',
#   'firstName': 'DrAlbert',
#   'job': 'Com/MEPD',
#   'lastName': 'Musisi',
#   'middleName': None,
#   'office': 'Macro Economic Policy',
#   'roomContact': '7217'},
#  {'email': '',
#   'firstName': 'Moses',
#   'job': 'Principal Economist',
#   'lastName': 'Kabanda',
#   'middleName': None,
#   'office': 'Macro Economic Policy',
#   'roomContact': '7228'},
#  {'email': '',
#   'firstName': 'Moses',
#   'job': 'Techinal Advisor/Econ.Affairs',
#   'lastName': 'Bekabye',
#   'middleName': None,
#   'office': 'Macro Economic Policy',
#   'roomContact': '7226'},
#  {'email': '',
#   'firstName': 'Joel',
#   'job': 'SE/Macro Modelling',
#   'lastName': 'Kantu',
#   'middleName': 'Muhinda',
#   'office': 'Macro Economic Modelling',
#   'roomContact': '7229'},
#  {'email': '',
#   'firstName': 'Justine',
#   'job': 'SE/Macro Modelling',
#   'lastName': 'Ayebare',
#   'middleName': None,
#   'office': 'Macro Economic Modelling',
#   'roomContact': '7221'},
#  {'email': '',
#   'firstName': 'Wilson',
#   'job': 'Economist/MMP',
#   'lastName': 'Asiimwe',
#   'middleName': None,
#   'office': 'Macro Economic Modelling',
#   'roomContact': '7404'},
#  {'email': '',
#   'firstName': 'Priscilla',
#   'job': 'Economist',
#   'lastName': 'Kisakye',
#   'middleName': None,
#   'office': 'Macro Economic Modelling',
#   'roomContact': '7221'},
#  {'email': '',
#   'firstName': 'Susan',
#   'job': 'Economist',
#   'lastName': 'Ayinyo',
#   'middleName': None,
#   'office': 'Macro Economic Modelling',
#   'roomContact': '7221'},
#  {'email': '',
#   'firstName': 'Racheal',
#   'job': 'Economist',
#   'lastName': 'Nuwamanya',
#   'middleName': None,
#   'office': 'Macro Economic Modelling',
#   'roomContact': '7221'},
#  {'email': '',
#   'firstName': 'Davis',
#   'job': 'Econ/Macro Modelling',
#   'lastName': 'Vuningoma',
#   'middleName': None,
#   'office': 'Macro Economic Modelling',
#   'roomContact': '7404'},
#  {'email': '',
#   'firstName': 'Mustapha',
#   'job': 'Ag. AC',
#   'lastName': 'Achidri',
#   'middleName': None,
#   'office': 'Economic Analysis Section',
#   'roomContact': '7222'},
#  {'email': '',
#   'firstName': 'Rosett',
#   'job': 'Senior Economist',
#   'lastName': 'Nakavuma',
#   'middleName': None,
#   'office': 'Economic Analysis Section',
#   'roomContact': '7220'},
#  {'email': '',
#   'firstName': 'Caroline',
#   'job': 'Economist',
#   'lastName': 'Namukwaya',
#   'middleName': None,
#   'office': 'Economic Analysis Section',
#   'roomContact': '7220'},
#  {'email': '',
#   'firstName': 'Clare',
#   'job': 'Economist',
#   'lastName': 'Nyakahuma',
#   'middleName': None,
#   'office': 'Economic Analysis Section',
#   'roomContact': '7220'},
#  {'email': '',
#   'firstName': 'Anne',
#   'job': 'Graduate Economist',
#   'lastName': 'Nanziri',
#   'middleName': None,
#   'office': 'Economic Analysis Section',
#   'roomContact': '7220'},
#  {'email': '',
#   'firstName': 'Oscar',
#   'job': 'Senior Economist',
#   'lastName': 'Ayebazibwe',
#   'middleName': None,
#   'office': 'Fiscal Management Section',
#   'roomContact': '7230'},
#  {'email': '',
#   'firstName': 'Elaine',
#   'job': 'Senior Economist',
#   'lastName': 'Abomwesigwa',
#   'middleName': None,
#   'office': 'Fiscal Management Section',
#   'roomContact': '7399'},
#  {'email': '',
#   'firstName': 'Francis',
#   'job': 'Economist',
#   'lastName': 'Ahimbisibwe',
#   'middleName': None,
#   'office': 'Fiscal Management Section',
#   'roomContact': '7399'},
#  {'email': '',
#   'firstName': 'Obadia',
#   'job': 'Economist',
#   'lastName': 'Turinawe',
#   'middleName': None,
#   'office': 'Fiscal Management Section',
#   'roomContact': '7399'},
#  {'email': '',
#   'firstName': 'Yasin',
#   'job': 'Principal Economist',
#   'lastName': 'Mayanja',
#   'middleName': 'Sadiq',
#   'office': 'External Financial Analysis Section',
#   'roomContact': '7225'},
#  {'email': '',
#   'firstName': 'Esther',
#   'job': 'Economist',
#   'lastName': 'Aguti',
#   'middleName': None,
#   'office': 'External Financial Analysis Section',
#   'roomContact': '7225'},
#  {'email': '',
#   'firstName': 'Flavia',
#   'job': 'Senior Economist',
#   'lastName': 'Nasobora',
#   'middleName': None,
#   'office': 'External Financial Analysis Section',
#   'roomContact': '7225'},
#  {'email': '',
#   'firstName': 'Musiime',
#   'job': 'Economist',
#   'lastName': 'Atuha',
#   'middleName': 'Joanah',
#   'office': 'External Financial Analysis Section',
#   'roomContact': '7225'},
#  {'email': '',
#   'firstName': 'Esther',
#   'job': 'Personal Secretary',
#   'lastName': 'Nabaweesi',
#   'middleName': None,
#   'office': 'Administrative Section',
#   'roomContact': '7218'},
#  {'email': '',
#   'firstName': 'Juliet',
#   'job': 'Stenographer Secretary',
#   'lastName': 'Namono',
#   'middleName': None,
#   'office': 'Administrative Section',
#   'roomContact': '7218'},
#  {'email': '',
#   'firstName': 'Santa',
#   'job': 'Office Attendant',
#   'lastName': 'Akum',
#   'middleName': None,
#   'office': 'Administrative Section',
#   'roomContact': '7218'},
#  {'email': '',
#   'firstName': 'Denis',
#   'job': 'Office Attendant',
#   'lastName': 'Otigo',
#   'middleName': None,
#   'office': 'Administrative Section',
#   'roomContact': '7218'}]

# %%
processed_filename = 'processed_finances.json'
with open(processed_filename, 'w') as f:
    json.dump(to_json(), f)

# %%
with open(processed_filename) as f:
    print(f.read())
# Out:
# [{"firstName": "Lawrence", "lastName": "Semakula", "middleName": null, "email": "", "job": "Accountant General", "roomContact": "7115", "office": "Accountant General's Office"}, {"firstName": "Godfrey", "lastName": "Ssemugoma", "middleName": null, "email": "", "job": "Ag.Director/FMS", "roomContact": "7117", "office": "Financial Management Services"}, {"firstName": "Aiden", "lastName": "Rujumba", "middleName": null, "email": "", "job": "Ag. C/FMSD", "roomContact": "7259", "office": "Financial Management Services"}, {"firstName": "Jane", "lastName": "Enyaku", "middleName": null, "email": "", "job": "Personal Secretary/AG", "roomContact": "7919", "office": "Accountant General's Office"}, {"firstName": "Arthur", "lastName": "Mugweri", "middleName": null, "email": "", "job": "Ag. Comm/IFMS", "roomContact": "7933", "office": "Management Information Systems-MIS/IFMS"}, {"firstName": "Daniel", "lastName": "Lubowa", "middleName": null, "email": "", "job": "Sen. Sytems Analyst", "roomContact": "7917", "office": "Management Information Systems-MIS/IFMS"}, {"firstName": "Edward", "lastName": "Oweyesigire", "middleName": null, "email": "", "job": "Office Attendant", "roomContact": "7256", "office": "Accountant General's Office"}, {"firstName": "Robert", "lastName": "Izimba", "middleName": null, "email": "", "job": "Driver", "roomContact": "7256", "office": "Accountant General's Office"}, {"firstName": "Prudence", "lastName": "Rwangoga", "middleName": "Ayebazibwe", "email": "", "job": "AC/HR/Treasury", "roomContact": "7273", "office": "Accountant General's Office"}, {"firstName": "Lucy", "lastName": "Acen", "middleName": null, "email": "", "job": "PHRO", "roomContact": "7296", "office": "Accountant General's Office"}, {"firstName": "Lindah", "lastName": "Nanziri", "middleName": null, "email": "", "job": "HRO", "roomContact": "7924", "office": "Accountant General's Office"}, {"firstName": "Nakyama", "lastName": "Bridget", "middleName": null, "email": "", "job": "SHRO", "roomContact": "7924", "office": "Accountant General's Office"}, {"firstName": "Owuma", "lastName": "Gilbert", "middleName": null, "email": "", "job": "Research Officer", "roomContact": "7924", "office": "Accountant General's Office"}, {"firstName": "Agnes", "lastName": "Nayiga", "middleName": null, "email": "", "job": "Records Assistant", "roomContact": "7924", "office": "Accountant General's Office"}, {"firstName": "Margrate", "lastName": "Apio", "middleName": null, "email": "", "job": "Accounts Assistant", "roomContact": "7924", "office": "Accountant General's Office"}, {"firstName": "Jennifer", "lastName": "Rugunda", "middleName": "Nyakato", "email": "", "job": "Asst. Records Officer", "roomContact": "7373", "office": "Accountant General's Office"}, {"firstName": "Steven", "lastName": "Medo", "middleName": "Godfrey", "email": "", "job": "Records Assistant", "roomContact": "7373", "office": "Accountant General's Office"}, {"firstName": "Agnes", "lastName": "Naiga", "middleName": null, "email": "", "job": "Records Assistant", "roomContact": "7373", "office": "Accountant General's Office"}, {"firstName": "Modo", "lastName": "Ruth", "middleName": null, "email": "", "job": "Sen. Records Officer", "roomContact": "7355", "office": "Accountant General's Office"}, {"firstName": "Jackline", "lastName": "Adong", "middleName": null, "email": "", "job": "Office Attendant", "roomContact": "7355", "office": "Accountant General's Office"}, {"firstName": "Joyce", "lastName": "Acen", "middleName": null, "email": "", "job": "Librarian", "roomContact": "7299", "office": "Accountant General's Office"}, {"firstName": "Mariam", "lastName": "Mukabya", "middleName": null, "email": "", "job": "Asst. Librarian", "roomContact": "7299", "office": "Accountant General's Office"}, {"firstName": "Catherine", "lastName": "Kyomugisha", "middleName": null, "email": "", "job": "Asst. Librarian", "roomContact": "7299", "office": "Accountant General's Office"}, {"firstName": "Wilberforce", "lastName": "Wandera ...

# %%
# add with that, we are DONE!

# %%
git
