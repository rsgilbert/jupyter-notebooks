# %%
# Utils

# %%
# Generate excel sheet

# %%
import pandas as pd

# %%
# variables
filename = 'others-sitename-profile.xlsx'

# %%
# writer to excel
def writer_excel(filename):
    writer = pd.ExcelWriter(filename, engine='xlsxwriter')
    return writer

# %%
def write_excel_rows(col1, col2, writer, sheet_name="sheet1"):
    df = pd.DataFrame({
        'Sitename': col1,
#         'Profile Image': col2
    })
    df.to_excel(writer, sheet_name=sheet_name, index=False)
    writer.save()

# %%
# read excel sheet
def read_excel(filename):
    reader = pd.read_excel(filename)
    print(reader)

# %%
read_excel(filename)
# Out:
#    Sitename Profile Image
# 0         1             k
# 1         2             a
# 2         3             d

# %%
sites = ['Abim',
 'Abim District Local Government',
 'Adjumani District Local Government',
 'Agago District Local Government',
 'Alebtong',
 'Alebtong District Local Government',
 'Amolatar District Local Government',
 'Amuria Local Government',
 'Amuru Local Government',
 'Apac Local Government',
 'Apac Municipality',
 'Arua',
 'Arua Local Government',
 'Arua Municipality',
 'Arua hospital',
 'Audit',
 'Audit Sys',
 'Budaka',
 'Bugiri District Local Government',
 'Bugiri Municipality',
 'Buikwe',
 'Buikwe Local Government',
 'Bukedea Local Government',
 'Bukwo Local Government',
 'Buliisa District Local Government',
 'Bundibugyo Local Government',
 'Bunyangabu Local Government',
 'Bushenyi Local Government',
 'Busia Local Government',
 'Busia Municipality',
 'Busitema',
 'Butaleja District Local Government',
 'Butaleja Local Government',
 'Butambala Local Government',
 'Buvuma Local Government',
 'Buyende',
 'Buyende Local Government',
 'Cdo Gl',
 'Dda',
 'Dei',
 'Dfps Gl',
 'Dokolo Local Government',
 'Ec',
 'Entebbe Municipality',
 'Esc',
 'Fia Gl',
 'Fort Municipality',
 'Gl',
 'Gomba Local Government',
 'Gulu',
 'Gulu Local Government',
 'Gulu Municipality',
 'Gulu-uni',
 'Gulu-uni Gl',
 'Hod',
 'Hoima Local Government',
 'Hoima Municipality',
 'Ibanda District Local Government',
 'Ibanda Municipality',
 'Iganga Local Government',
 'Iganga Municipality',
 'Igg',
 'Ishaka Municipality',
 'Isingiro Local Government',
 'Jinja',
 'Jinja Local Government',
 'Jinja Municipality',
 'Jsc',
 'Judiciary',
 'Kab Gl',
 'Kabale',
 'Kabale District Local Government',
 'Kabale Municipality',
 'Kabarole Local Government',
 'Kaberamaido Local Government',
 'Kalangala Local Government',
 'Kaliro',
 'Kaliro Local Government',
 'Kamuli District Local Government',
 'Kamuli Municipality',
 'Kamwenge',
 'Kamwenge Local Government',
 'Kanungu District Local Government',
 'Kapchorwa Local Government',
 'Kapchorwa Municipality',
 'Kasese District Local Government',
 'Kasese Municipality',
 'Katakwi Local Government',
 'Kayunga District Local Government',
 'Kcca',
 'Kcca Gl',
 'Kibaale District Local Government',
 'Kibaale Local Government',
 'Kiboga District Local Government',
 'Kiboga Local Government',
 'Kibuku',
 'Kira Municipality',
 'Kiruhura District Local Government',
 'Kiryandongo District Local Government',
 'Kisoro District Local Government',
 'Kisoro Municipality',
 'Kitgum Local Government',
 'Kitgum Municipality',
 'Koboko Local Government',
 'Koboko Municipality',
 'Kole Local Government',
 'Kotido Local Government',
 'Kotido Municipality',
 'Kumi Local Government',
 'Kumi Municipality',
 'Kween Local Government',
 'Kyankwanzi Local Government',
 'Kyegegwa District Local Government',
 'Kyenjojo Local Government',
 'Kyu',
 'Kyu Gl',
 'Ldc Gl',
 'Lira',
 'Lira Municipality',
 'Lirauni Gl',
 'Lugazi Municipality',
 'Luwero District Local Government',
 'Lwengo Local Government',
 'Lyantonde District Local Government',
 'Maaif',
 'Main',
 'Mak',
 'Mak Gl',
 'Makindye-ssa Municipality',
 'Manafwa Local Government',
 'Maracha',
 'Masaka',
 'Masaka Municipality',
 'Masindi District Local Government',
 'Masindi Municipality',
 'Mayuge',
 'Mayuge District Local Government',
 'Mbale',
 'Mbale Municipality',
 'Mbarara',
 'Mbarara Local Government',
 'Mbarara Municipality',
 'Meaca',
 'Memd',
 'Mglsd',
 'Ministry of Health',
 'Mitooma Local Government',
 'Mityana District Local Government',
 'Mityana Local Government',
 'Mityana Municipality',
 'Mod',
 'Moes',
 'Mofa',
 'Mofped',
 'Mofped Gl',
 'Moia',
 'Moict',
 'Moict Gl',
 'Mojca',
 'Molg',
 'Mops',
 'Moroto District Local Government',
 'Moroto Municipality',
 'Mowe',
 'Moyo Local Government',
 'Mpigi',
 'Mubende Local Government',
 'Mubende Municipality',
 'Mubs',
 'Muk',
 'Mukono Local Government',
 'Mukono Municipality',
 'Muni-uni Gl',
 'Must',
 'Naads',
 'Nakaseke District Local Government',
 'Nakasongola District Local Government',
 'Namayingo Local Government',
 'Namutumba Local Government',
 'Nansana Municipality',
 'Naro',
 'Naro Gl',
 'Ncdc',
 'Nebbi Local Government',
 'Nebbi Municipality',
 'Ngora Local Government',
 'Nira',
 'Nms Gl',
 'Npa',
 'Ntungamo Local Government',
 'Ntungamo Municipality',
 'Nwoya Local Government',
 'Oag',
 'Office of the Prime Minister',
 'Op',
 'Otuke Local Government',
 'Oyam Local Government',
 'Pader Local Government',
 'Pakwach Local Government',
 'Pallisa Local Government',
 'Parl',
 'Police',
 'Ppda',
 'Preferences',
 'Psa',
 'Psc',
 'Rakai',
 'Rea',
 'Rubirizi Local Government',
 'Rukungiri District Local Government',
 'Rukungiri Local Government',
 'Rukungiri Municipality',
 'Sembabule District Local Government',
 'Serere Local Government',
 'Sh',
 'Sheema Local Government',
 'Sheema Municipality',
 'Sironko Local Government',
 'Soroti',
 'Soroti Municipality',
 'Tororo',
 'Tororo Municipality',
 'Treasury',
 'Ucda',
 'Ucda Gl',
 'Uia',
 'Ulc',
 'Umi',
 'Unbs',
 'Uneb Gl',
 'Unra',
 'Ursb',
 'Wakiso',
 'Yumbe Local Government',
 'Zombo']

# %%
write_excel_rows(sites,[], writer_excel(filename), sheet_name="Sitenames with profile images")
